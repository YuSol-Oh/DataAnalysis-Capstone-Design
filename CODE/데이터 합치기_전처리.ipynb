# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/Shareddrives/데캡디 TEAM G/DATA/전처리 후 데이터/'

# %%
import pandas as pd
import os

# %%
df = pd.read_csv(os.path.join(path+"recipe_밑반찬2.csv"), encoding = 'utf-8')

# %%
df.head()
# Out:
#               레시피 제목        요리명  \
# 0    두부에 꼬리가 달렸어요!!         NaN
# 1           가정식 두부조림       두부조림
# 2          초간단 어묵 볶음       어묵볶음
# 3          상큼상큼 오이무침       오이무침
# 4  질기지 않아요 오징어청양고추조림  오징어청양고추조림
#
#                                               요리재료내용  \
# 0  | 두부 1/2모| 당근 1/2개| 고추 2개| 브로콜리 1/4개| 새우 4마리| ...
# 1  | 손두부 1모| 포도씨유| 소금 약간| 꽈리고추 1줌| 양파 1/2개| 대파 1줄...
# 2  | 어묵 500g| 포도씨유 적당량 | 꽈리고추 1줌| 양파 1/2개| 느타리버섯 ...
# 3  | 오이 1개 | 소금 1작은술| 대파다진것 1큰술| 마늘 1작은술| 고추장1작은술...
# 4  | 오징어링 500g| 마른고추 큰것 2~3개| 다시마 약간| 통마늘 4개| 청양고...
#
#                                                 요리재료
# 0                           두부 당근 고추 브로콜리 새우 녹말가루 계란
# 1  손두부 포도씨유 소금 꽈리고추 양파 대파 간장 물 설탕 물엿 굴소스 고춧가루 마늘 ...
# 2  어묵 포도씨유 꽈리고추 양파 느타리버섯 대파 물 간장 물 설탕 물엿 굴소스 고춧가루...
# 3       오이 소금 대파다진것 마늘 고추장1작은술 고춧가루 설탕 깨소금 식초 참기름 통깨
# 4     오징어링 마른고추 다시마 통마늘 청양고추 물 맛간장 생강맛술 올리고당 설탕 후춧가루

# %%
# df = df[['레시피 제목','요리명', '요리종류별명', '요리재료내용']]

# %%
df['레시피내용'] = 0

# %%
df.head()
# Out:
#               레시피 제목        요리명  \
# 0    두부에 꼬리가 달렸어요!!         NaN
# 1           가정식 두부조림       두부조림
# 2          초간단 어묵 볶음       어묵볶음
# 3          상큼상큼 오이무침       오이무침
# 4  질기지 않아요 오징어청양고추조림  오징어청양고추조림
#
#                                               요리재료내용  \
# 0  | 두부 1/2모| 당근 1/2개| 고추 2개| 브로콜리 1/4개| 새우 4마리| ...
# 1  | 손두부 1모| 포도씨유| 소금 약간| 꽈리고추 1줌| 양파 1/2개| 대파 1줄...
# 2  | 어묵 500g| 포도씨유 적당량 | 꽈리고추 1줌| 양파 1/2개| 느타리버섯 ...
# 3  | 오이 1개 | 소금 1작은술| 대파다진것 1큰술| 마늘 1작은술| 고추장1작은술...
# 4  | 오징어링 500g| 마른고추 큰것 2~3개| 다시마 약간| 통마늘 4개| 청양고...
#
#                                                 요리재료  레시피내용
# 0                           두부 당근 고추 브로콜리 새우 녹말가루 계란      0
# 1  손두부 포도씨유 소금 꽈리고추 양파 대파 간장 물 설탕 물엿 굴소스 고춧가루 마늘 ...      0
# 2  어묵 포도씨유 꽈리고추 양파 느타리버섯 대파 물 간장 물 설탕 물엿 굴소스 고춧가루...      0
# 3       오이 소금 대파다진것 마늘 고추장1작은술 고춧가루 설탕 깨소금 식초 참기름 통깨      0
# 4     오징어링 마른고추 다시마 통마늘 청양고추 물 맛간장 생강맛술 올리고당 설탕 후춧가루      0

# %%
path = '/content/drive/Shareddrives/데캡디 TEAM G/DATA/만개의 레시피 데이터/'

# %%
df_2 = pd.read_csv(os.path.join(path+"recipe_밑반찬.csv"), encoding = 'utf-8')

# %%
df_2.head()
# Out:
#                                 Menu  \
# 0  버섯으로 관자 느낌 내는 방법! 새송이버섯간장버터구이 만들기
# 1                달콤 짭조름♡ 떡 베이컨 간장조림♡
# 2                            봄동 된장무침
# 3                           간장 어묵 볶음
# 4                 [식약처] 고사리파전 & 단감전
#
#                                           Ingredient  \
# 0  ['새송이버섯2개', '버터30g', '어린잎채소', '간장1T', '맛술1T', ...
# 1        ['베이컨', '대파', '떡', '간장', '참기름', '물엿', '기름']
# 2  ['데쳐서물기짠봄동600그람', '다진파2큰술', '다진마늘1큰술', '된장2큰술'...
# 3  ['어묵240g', '양파1/2개', '당근1/4개', '통깨약간', '식용유적당량...
# 4  ['고사리30g', '쪽파7g', '홍고추6g', '계란20g', '밀가루20g',...
#
#                                               Recipe
# 0  ['버섯의 밑동과 갓을 잘라낸 뒤, 3~4등분 한다', '자른버섯의 양면에 칼집을 ...
# 1  ['대파에 떡국떡 (가래떡, 떡볶이떡) 베이컨', '기름두르고 볶듯구워요.(튀기듯하...
# 2  ['봄동은 잎이 연한것으로 고른다.', '잎을 떼어 끓는 물에 소금을 넣고 데친다....
# 3  ['어묵을 썰어 끓는 물에 30초 가량 데쳐 주세요.', '양파를 1/2개 채 썰어...
# 4  ['재료를 준비한다.', '고사리와 쪽파는 길이를 반으로 자르고, 홍고추는 길이는 ...

# %%
for i in range(len(df_2)) :
    for j in range(len(df)) :
        if(df['레시피 제목'][j] == df_2['Menu'][i]) :
            idx = j
            df['레시피내용'][idx] = df_2['Recipe'][i]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
for i in range(len(df)) :
    if(df['레시피내용'][i] != 0) :
        print(df.loc[i])
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 레시피내용     ['재료를 준비해요', '귤 껍질은 다 까고 오이껍질은 훌듯이 대충 깍아주세요오이는...
# Name: 24250, dtype: object
# 레시피 제목                   고향이 강원도인 아부지가 해주던 100프로 순수 감자전 만들기
# 요리명                                                     감자전
# 요리재료내용    | 감자 종이컵에 쏙들어가는사이즈로8알| 소금1/2 밥숟가락 | 대파 1대| 청양고...
# 요리재료                                       감자 소금1/2 대파 청양고추
# 레시피내용     ['그저께 감자국 끓일때 남아있던 감자깍아둔게 있어요.', '강판에 감자를 갈아주세...
# Name: 24252, dtype: object
# 레시피 제목                            [집밥] 건시래기로 시래기나물볶음 만드는 법
# 요리명                                                 시래기나물볶음
# 요리재료내용    | 건시래기 150g| 식용유 1T| 들기름 3T| 국간장 3T| 액젓 1T| 다진...
# 요리재료                             건시래기 식용유 들기름 국간장 액젓 다진마늘 깨
# 레시피내용     ['건시래기는 먼저 큰 냄비에 담아 푹 삶아주세요.1시간 30분~2시간 정도 중불에...
# Name: 24253, dtype: object
# 레시피 제목                                                진미채볶음
# 요리명                                                   진미채볶음
# 요리재료내용    | 진미채 250g | 마요네즈 1큰술| 간장 2/1소주잔| 식용유 2/1소주잔| ...
# ...

# %%
df.to_csv('최종recipe_밑반찬.csv',index=False, encoding="utf-8-sig")
